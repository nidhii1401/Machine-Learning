# %% [markdown]
# <a href="https://colab.research.google.com/github/nidhii1401/Machine-Learning/blob/main/ML_Linear_Regression_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
#generate random dataset
np.random.seed(0)
x=np.random.rand(100,1)

# %%
#generate 2D array with 100 rows and each row containing 1 random number
y=2+3*x+np.random.rand(100,1)
regression_model = LinearRegression()

# %%
#Model Initialisation
regression_model.fit(x,y)
# Out:
# LinearRegression()

# %%
#Training the data
y_predicted = regression_model.predict(x)

# %%
#Predicting
rmse = mean_squared_error(y,y_predicted)
r2 = r2_score(y,y_predicted)

# %%
#Printing Values
print("Slope:",regression_model.coef_)
print("Intercept:",regression_model.intercept_)
print("Root Mean Squared Error:",rmse)
print("R2 Score:",r2)
# Out:
# Slope: [[2.93655106]]
# Intercept: [2.55808002]
# Root Mean Squared Error: 0.07623324582875007
# R2 Score: 0.9038655568672764

# %%
#Plotting Values and data plot
plt.scatter(x,y,s=10)
plt.xlabel("x_Values from 0-1")
plt.ylabel("y_Values from 2")
# Out:
# Text(0, 0.5, 'y_Values from 2')

# %%
#Predicted Values
plt.plot(x,y_predicted,color="red")
plt.show()
